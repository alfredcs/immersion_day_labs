# %% [markdown]
# ## Module 10: Model Training Validation, Debugger and XAI

# %% [markdown]
# ### 1. Customer Retention Retail Dataset

# %% [markdown]
# This dataset can be used to understand what are the various marketing strategy based on consumer behaviour that can be adopted to increase customer retention of a retail store.
#
# An online tea retail store which sells tea of different flavors across various cities in India. The dataset contains data about the store's customers, their orders, quantity ordered, order frequency, city,etc. This is a large dataset which will help in analysis.
#
# Reference: https://www.kaggle.com/uttamp/store-data

# %%
# %%html
# <style>
# table {float:left}
# </style>
# Out:
# <style>
# table {float:left}
# </style>

# %% [markdown]
# ### 2. Import Packages and Constants

# %% [markdown]
# Install shap and smdebug packages if not already installed and restart kernel after installing the packages

# %%
# !conda install -c conda-forge shap --yes
# !pip install smdebug --upgrade

# %%
import re
import s3fs
import shap
import time
import boto3
import pandas as pd
import numpy as np

from itertools import islice
import matplotlib.pyplot as plt

import sagemaker
from sagemaker.xgboost.estimator import XGBoost
from sagemaker.session import Session
from sagemaker.inputs import TrainingInput
from sagemaker.debugger import DebuggerHookConfig,CollectionConfig
from sagemaker.debugger import rule_configs, Rule
from smdebug.trials import create_trial
from sagemaker.tuner import (
    IntegerParameter,
    CategoricalParameter,
    ContinuousParameter,
    HyperparameterTuner
)
# Out:
# [2021-12-08 22:30:19.814 ip-172-31-61-161.us-west-2.compute.internal:11688 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None

# %%
#Replace this value with the S3 Bucket Created
sagemaker_session = sagemaker.Session()
default_bucket=None
if default_bucket is None and sagemaker_session is not None:
    # set to default bucket if a bucket name is not given
    default_bucket = sagemaker_session.default_bucket()
s3_prefix = 'alfab3/churn'

# %%
#role = sagemaker.get_execution_role()
role = 'arn:aws:iam::976939723775:role/service-role/AmazonSageMaker-ExecutionRole-20210317T133000'
region = sagemaker_session.boto_region_name

# %% [markdown]
# ### 3. Preprocess Data

# %% [markdown]
# def preprocess_data(file_path):
#     df = pd.read_csv(file_path)
#     ## Convert to datetime columns
#     df["firstorder"]=pd.to_datetime(df["firstorder"],errors='coerce')
#     df["lastorder"] = pd.to_datetime(df["lastorder"],errors='coerce')
#     ## Drop Rows with null values
#     df = df.dropna()
#     ## Create Column which gives the days between the last order and the first order
#     df["first_last_days_diff"] = (df['lastorder']-df['firstorder']).dt.days
#     ## Create Column which gives the days between when the customer record was created and the first order
#     df['created'] = pd.to_datetime(df['created'])
#     df['created_first_days_diff']=(df['created']-df['firstorder']).dt.days
#     ## Drop Columns
#     df.drop(['custid','created','firstorder','lastorder'],axis=1,inplace=True)
#     ## Apply one hot encoding on favday and city columns
#     df = pd.get_dummies(df,prefix=['favday','city'],columns=['favday','city'])
#     return df

# %%
#churn_train_data = preprocess_data(f"s3://{default_bucket}/alfab3/samples/storedata_total.csv")
churn_train_data = pd.read_csv(f"s3://{default_bucket}/{s3_prefix}/transformed/transformed.csv")

# %% [markdown]
# Pop the 'churn' column to the first position

# %%
churn_col = churn_train_data.pop('churn')
churn_train_data.insert(0, 'churn', churn_col)
churn_train_data.head(20)
# Out:
#     churn  sex  is_married  discount_offerred_num  discount_amount_total  \
# 0       0    1           0                   0.30               0.121275
# 1       0    0           1                   0.00               0.000000
# 2       0    0           1                   0.00               0.000000
# 3       0    0           1                   0.00               0.000000
# 4       0    0           1                   0.00               0.000000
# 5       0    0           1                   0.00               0.000000
# 6       0    0           1                   0.00               0.000000
# 7       0    0           1                   0.00               0.000000
# 8       0    0           1                   0.00               0.000000
# 9       0    1           1                   0.85               0.769825
# 10      0    1           1                   0.85               0.769825
# 11      0    1           1                   0.85               0.769825
# ...

# %% [markdown]
# ##### Normalize review_headline and review_body columns
#
# To eliminate - sign and restrict score to [0,1]

# %%
#churn_train_data['review_headline']= (churn_train_data['review_headline']-churn_train_data['review_headline'].mean())/churn_train_data['review_headline'].std()
churn_train_data['review_headline']=(churn_train_data['review_headline']-churn_train_data['review_headline'].min())/(churn_train_data['review_headline'].max()-churn_train_data['review_headline'].min())
churn_train_data['review_headline'] = round(churn_train_data['review_headline'], 4)
churn_train_data['review_body']=(churn_train_data['review_body']-churn_train_data['review_body'].min())/(churn_train_data['review_body'].max()-churn_train_data['review_body'].min())
churn_train_data['review_body'] = round(churn_train_data['review_body'], 4)

# %%
churn_train_data = churn_train_data.drop(['purchased_on'], axis=1)

# %%
churn_train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1332094 entries, 0 to 1332093
# Data columns (total 35 columns):
#  #   Column                         Non-Null Count    Dtype
# ---  ------                         --------------    -----
#  0   churn                          1332094 non-null  int64
#  1   sex                            1332094 non-null  int64
#  2   is_married                     1332094 non-null  int64
#  3   discount_offerred_num          1332094 non-null  float64
#  4   discount_amount_total          1332094 non-null  float64
#  5   customer_service_calls         1332094 non-null  float64
#  6   age_18-29                      1332094 non-null  int64
#  7   age_30-39                      1332094 non-null  int64
#  8   age_40-49                      1332094 non-null  int64
#  9   age_50-59                      1332094 non-null  int64
#  10  age_60-69                      1332094 non-null  int64
#  11  age_70-plus                    1332094 non-null  int64
# ...

# %%
import seaborn as sns
sns.pairplot(churn_train_data[['churn', 'discount_offerred_num','customer_service_calls','review_body']])

# %%
sns.countplot(churn_train_data['churn'])
# Out:
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# <AxesSubplot:xlabel='churn', ylabel='count'>

# %% [markdown]
# ### 4. Split Train, Test and Validation Datasets

# %%
def split_datasets(df):
    #y=df.pop("retained") #original
    y=df.pop("is_reordered")
    X_pre = df
    y_pre = y.to_numpy().reshape(len(y),1)
    feature_names = list(X_pre.columns)
    X= np.concatenate((y_pre,X_pre),axis=1)
    np.random.shuffle(X)
    train,validation,test=np.split(X,[int(.7*len(X)),int(.85*len(X))])
    return feature_names,train,validation,test

# %%
feature_names,train,validation,test = split_datasets(churn_train_data)

# %%
pd.DataFrame(test).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199815 entries, 0 to 199814
# Data columns (total 35 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   0       199815 non-null  float64
#  1   1       199815 non-null  float64
#  2   2       199815 non-null  float64
#  3   3       199815 non-null  float64
#  4   4       199815 non-null  float64
#  5   5       199815 non-null  float64
#  6   6       199815 non-null  float64
#  7   7       199815 non-null  float64
#  8   8       199815 non-null  float64
#  9   9       199815 non-null  float64
#  10  10      199815 non-null  float64
#  11  11      199815 non-null  float64
#  12  12      199815 non-null  float64
#  13  13      199815 non-null  float64
#  14  14      199815 non-null  float64
#  15  15      199815 non-null  float64
#  16  16      199815 non-null  float64
#  17  17      199815 non-null  float64
#  18  18      199815 non-null  float64
#  19  19      199815 non-null  float64
# ...

# %%
pd.DataFrame(train).to_csv(f"s3://{default_bucket}/{s3_prefix}/train/train.csv",header=False,index=False)
pd.DataFrame(validation).to_csv(f"s3://{default_bucket}/{s3_prefix}/validation/validation.csv",header=False,index=False)
pd.DataFrame(test).to_csv(f"s3://{default_bucket}/{s3_prefix}/test/test.csv",header=False,index=False)

# %%
# Try to get data from feature store. Comment out the original source
'''
s3_input_train = TrainingInput(
    s3_data=f"s3://{default_bucket}/data/train/",content_type="csv")
s3_input_validation = TrainingInput(
    s3_data=f"s3://{default_bucket}/data/validation/",content_type="csv")
'''
# Out:
# '\ns3_input_train = TrainingInput(\n    s3_data=f"s3://{default_bucket}/data/train/",content_type="csv")\ns3_input_validation = TrainingInput(\n    s3_data=f"s3://{default_bucket}/data/validation/",content_type="csv")\n'

# %% [markdown]
# ### 5. Hyperparameter Tuning HPO
#
# Define the train/validation data source from previous tasks

# %%
s3_input_train = TrainingInput(
    s3_data=f"s3://{default_bucket}/{s3_prefix}/train/", content_type="csv")
s3_input_validation = TrainingInput(
    s3_data=f"s3://{default_bucket}/{s3_prefix}/validation/",content_type="csv")

# %% [markdown]
# ### 4. Hyperparameter Tuning HPO

# %%
fixed_hyperparameters = {
    "eval_metric":"auc",
    "objective":"binary:logistic",
    "num_round":"100",
    "rate_drop":"0.3",
    "tweedie_variance_power":"1.4",
    "subsample":"0.7"
}

# %% [markdown]
# Use spot instance and HPO

# %%
sess = sagemaker.Session()
container = sagemaker.image_uris.retrieve("xgboost",region,"1.2-1")

## For spot instance only
use_spot_instances = True
max_run = 3600
max_wait = 7200 if use_spot_instances else None

estimator = sagemaker.estimator.Estimator(
    container,
    role,
    instance_count=1,
    hyperparameters=fixed_hyperparameters,
    instance_type="ml.m4.2xlarge",
    output_path="s3://{}/{}/output".format(default_bucket, s3_prefix),
    use_spot_instances=use_spot_instances,  # Need confirmation
    max_run=max_run,
    max_wait=max_wait,
    sagemaker_session=sagemaker_session
)

# %%
# AutoML HPO tuning
hyperparameter_ranges = {
    "eta": ContinuousParameter(0, 1),
    "min_child_weight": ContinuousParameter(1, 10),
    "alpha": ContinuousParameter(0, 2),
    "gamma":ContinuousParameter(2, 6),
    "max_depth": IntegerParameter(1, 10)
}

# %%
objective_metric_name = "validation:auc"

# %%
tuner = HyperparameterTuner(
    estimator,objective_metric_name,hyperparameter_ranges,max_jobs=10,max_parallel_jobs=4)

# %%
tuner.fit({
    "train":s3_input_train,
    "validation":s3_input_validation
    },include_cls_metadata=False)
# Out:
# ...............................................................................................................................................................................................!

# %%
tuning_job_result = boto3.client("sagemaker").describe_hyper_parameter_tuning_job(
    HyperParameterTuningJobName=tuner.latest_tuning_job.job_name
)

# %%
job_count = tuning_job_result["TrainingJobStatusCounters"]["Completed"]
print("%d training jobs have completed" %job_count)
# Out:
# 10 training jobs have completed

# %%
from pprint import pprint

if tuning_job_result.get("BestTrainingJob",None):
    print("Best Model found so far:")
    pprint(tuning_job_result["BestTrainingJob"])
else:
    print("No training jobs have reported results yet.")
# Out:
# Best Model found so far:
# {'CreationTime': datetime.datetime(2021, 12, 8, 22, 52, 3, tzinfo=tzlocal()),
#  'FinalHyperParameterTuningJobObjectiveMetric': {'MetricName': 'validation:auc',
#                                                  'Value': 0.6078400015830994},
#  'ObjectiveStatus': 'Succeeded',
#  'TrainingEndTime': datetime.datetime(2021, 12, 8, 22, 57, 45, tzinfo=tzlocal()),
#  'TrainingJobArn': 'arn:aws:sagemaker:us-west-2:976939723775:training-job/sagemaker-xgboost-211208-2242-009-2be2f011',
#  'TrainingJobName': 'sagemaker-xgboost-211208-2242-009-2be2f011',
#  'TrainingJobStatus': 'Completed',
#  'TrainingStartTime': datetime.datetime(2021, 12, 8, 22, 54, 44, tzinfo=tzlocal()),
#  'TunedHyperParameters': {'alpha': '0.3627385983850959',
#                           'eta': '0.2659054383823407',
#                           'gamma': '2.0',
#                           'max_depth': '10',
#                           'min_child_weight': '3.7321984726595394'}}

# %%
best_hyperparameters = tuning_job_result["BestTrainingJob"]["TunedHyperParameters"]

# %%
best_hyperparameters
# Out:
# {'alpha': '0.3627385983850959',
#  'eta': '0.2659054383823407',
#  'gamma': '2.0',
#  'max_depth': '10',
#  'min_child_weight': '3.7321984726595394'}

# %% [markdown]
# ### 7. XGBoost Model with SageMaker Debugger

# %%
hyperparameters = {**fixed_hyperparameters,**best_hyperparameters}
save_interval = 5
base_job_name = "demo-smdebug-xgboost-churn-classification"

# %%
container = sagemaker.image_uris.retrieve("xgboost",region,"1.2-1")

# %%
estimator = sagemaker.estimator.Estimator(
    container,
    role,
    base_job_name=base_job_name,
    instance_count=1,
    instance_type="ml.m4.xlarge",
    output_path="s3://{}/{}/output".format(default_bucket, s3_prefix),
    sagemaker_session=sess,
    hyperparameters=hyperparameters,
    max_run=1800,
    debugger_hook_config = DebuggerHookConfig(
        s3_output_path=f"s3://{default_bucket}/{s3_prefix}/debugger/",  # Required
        collection_configs=[
            CollectionConfig(
                name="metrics",
                parameters={
                    "save_interval": "5"
                }),
            CollectionConfig(
                name="feature_importance", parameters={"save_interval": "5"}
            ),
            CollectionConfig(name="full_shap", parameters={"save_interval": "5"}),
            CollectionConfig(name="average_shap", parameters={"save_interval": "5"}),
        ]
    ),
    rules=[
        Rule.sagemaker(
            rule_configs.loss_not_decreasing(),
            rule_parameters={
                "collection_names": "metrics",
                "num_steps": "10",
            },
        ),
    ]
)

# %%
estimator.fit(
        {"train":s3_input_train,"validation":s3_input_validation},wait=False
    )

# %%
for _ in range(36):
    job_name = estimator.latest_training_job.name
    client = estimator.sagemaker_session.sagemaker_client
    description = client.describe_training_job(TrainingJobName=job_name)
    training_job_status = description["TrainingJobStatus"]
    rule_job_summary = estimator.latest_training_job.rule_job_summary()
    rule_evaluation_status = rule_job_summary[0]["RuleEvaluationStatus"]
    print(
        "Training job status: {}, Rule Evaluation Status: {}".format(
            training_job_status, rule_evaluation_status
        )
    )
    if training_job_status in ["Completed", "Failed"]:
        break
    time.sleep(10)
# Out:
# Training job status: InProgress, Rule Evaluation Status: InProgress
# Training job status: InProgress, Rule Evaluation Status: InProgress
# Training job status: InProgress, Rule Evaluation Status: InProgress
# Training job status: InProgress, Rule Evaluation Status: InProgress
# Training job status: InProgress, Rule Evaluation Status: InProgress
# Training job status: InProgress, Rule Evaluation Status: InProgress
# Training job status: InProgress, Rule Evaluation Status: InProgress
# Training job status: InProgress, Rule Evaluation Status: InProgress
# Training job status: InProgress, Rule Evaluation Status: InProgress
# Training job status: InProgress, Rule Evaluation Status: InProgress
# Training job status: InProgress, Rule Evaluation Status: InProgress
# Training job status: InProgress, Rule Evaluation Status: InProgress
# Training job status: InProgress, Rule Evaluation Status: InProgress
# Training job status: InProgress, Rule Evaluation Status: InProgress
# ...

# %% [markdown]
# ### 8. Analyze Debugger Output

# %%
estimator.latest_training_job.rule_job_summary()
# Out:
# [{'RuleConfigurationName': 'LossNotDecreasing',
#   'RuleEvaluationJobArn': 'arn:aws:sagemaker:us-west-2:976939723775:processing-job/demo-smdebug-xgboost-churn-lossnotdecreasing-0a52ff88',
#   'RuleEvaluationStatus': 'InProgress',
#   'LastModifiedTime': datetime.datetime(2021, 12, 8, 23, 53, 14, 911000, tzinfo=tzlocal())},
#  {'RuleConfigurationName': 'ProfilerReport-1639006507',
#   'RuleEvaluationJobArn': 'arn:aws:sagemaker:us-west-2:976939723775:processing-job/demo-smdebug-xgboost-churn-profilerreport-1639006507-20cbb40a',
#   'RuleEvaluationStatus': 'InProgress',
#   'LastModifiedTime': datetime.datetime(2021, 12, 8, 23, 53, 16, 624000, tzinfo=tzlocal())}]

# %%
s3_output_path = estimator.latest_job_debugger_artifacts_path()
trial = create_trial(s3_output_path)
# Out:
# [2021-12-08 23:53:26.134 ip-172-31-61-161.us-west-2.compute.internal:11688 INFO s3_trial.py:42] Loading trial debug-output at path s3://sagemaker-us-west-2-976939723775/alfab3/churn/debugger/demo-smdebug-xgboost-churn-classificati-2021-12-08-23-35-07-258/debug-output

# %%
trial.tensor_names()
# Out:
# ['average_shap/f0',
#  'average_shap/f1',
#  'average_shap/f10',
#  'average_shap/f11',
#  'average_shap/f12',
#  'average_shap/f13',
#  'average_shap/f14',
#  'average_shap/f15',
#  'average_shap/f16',
#  'average_shap/f17',
#  'average_shap/f18',
#  'average_shap/f19',
#  'average_shap/f2',
#  'average_shap/f20',
#  'average_shap/f21',
#  'average_shap/f22',
#  'average_shap/f23',
#  'average_shap/f24',
#  'average_shap/f25',
#  'average_shap/f26',
#  'average_shap/f27',
#  'average_shap/f28',
#  'average_shap/f29',
#  'average_shap/f3',
#  'average_shap/f30',
#  'average_shap/f31',
#  'average_shap/f32',
#  'average_shap/f33',
#  'average_shap/f4',
#  'average_shap/f5',
#  'average_shap/f6',
#  'average_shap/f7',
#  'average_shap/f8',
#  'average_shap/f9',
#  'feature_importance/cover/f0',
#  'feature_importance/cover/f1',
#  'feature_importance/cover/f10',
#  'feature_importance/cover/f11',
#  'feature_importance/cover/f12',
#  'feature_importance/cover/f13',
# ...

# %%
trial.tensor("average_shap/f10").values()
# Out:
# {0: array([-6.7507794e-06], dtype=float32),
#  5: array([-8.660184e-06], dtype=float32)}

# %%
MAX_PLOTS = 35


def get_data(trial, tname):
    """
    For the given tensor name, walks though all the iterations
    for which you have data and fetches the values.
    Returns the set of steps and the values.
    """
    tensor = trial.tensor(tname)
    steps = tensor.steps()
    vals = [tensor.value(s) for s in steps]
    return steps, vals


def match_tensor_name_with_feature_name(tensor_name, feature_names=feature_names):
    feature_tag = tensor_name.split("/")
    for ifeat, feature_name in enumerate(feature_names):
        if feature_tag[-1] == "f{}".format(str(ifeat)):
            return feature_name
    return tensor_name


def plot_collection(trial, collection_name, regex=".*", figsize=(8, 6)):
    """
    Takes a `trial` and a collection name, and
    plots all tensors that match the given regex.
    """
    fig, ax = plt.subplots(figsize=figsize)
    tensors = trial.collection(collection_name).tensor_names
    matched_tensors = [t for t in tensors if re.match(regex, t)]
    for tensor_name in islice(matched_tensors, MAX_PLOTS):
        steps, data = get_data(trial, tensor_name)
        ax.plot(steps, data, label=match_tensor_name_with_feature_name(tensor_name))

    ax.legend(loc="center left", bbox_to_anchor=(1, 0.5))
    ax.set_xlabel("Iteration")

# %%
plot_collection(trial, "metrics")

# %%
def plot_feature_importance(trial, importance_type="weight"):
    SUPPORTED_IMPORTANCE_TYPES = ["weight", "gain", "cover", "total_gain", "total_cover"]
    if importance_type not in SUPPORTED_IMPORTANCE_TYPES:
        raise ValueError(f"{importance_type} is not one of the supported importance types.")
    plot_collection(trial, "feature_importance", regex=f"feature_importance/{importance_type}/.*")

# %%
plot_feature_importance(trial, importance_type="cover")

# %% [markdown]
# ### Explainable AI (XAI)
#
# Aim a making AI model understandble to humans
#
# One of the most popular methods today, SHAP (SHapley Additive exPlanations) is a game theory based approach to explain the output of any ML model. It connects optimal credit allocation with local explanations using the classic Shapley values from game theory and their related extensions.
#
# ![image.png](attachment:7a82f27e-9742-4bf2-a2f1-5961ea502089.png)
#
# SHAP helps you understand the magnitude of impact (length of the bar) and direction(colour) below.
#
# ![image.png](attachment:b89043aa-f29a-4b1a-9ba2-32a4f944fd40.png)
#
# SHAP is a model agnostic framework. More details on the methodology can be found on their page and in papers such as the one by Lundberg and Lee . Another good article to understand the math with an example oriented explanation by Ula La Paris can be read here. This package which is now easily one of the most popular choices has evolved over the last few years with intuitive and engaging visualizations across various aspects of model explainability. Some visualizations are given below followed by the code to generate these.
#
# ![image.png](attachment:2da130ff-dfbe-41c8-af72-aa8f45d64440.png)

# %%
plot_collection(trial, "average_shap")

# %% [markdown]
# ### Global Explanations
#
# Global interpretability provides a complete view on the operation of AI systems e.g. through listing the rules or features that determine their outcomes. i.e. a global interpretability system will provide the full set of ruls that are used by a Churn model to determine if a customer is at risk of churning.

# %%
shap_values = trial.tensor("full_shap/f1").value(trial.last_complete_step)
shap_no_base = shap_values[:, :-1]
shap_base_value = shap_values[0, -1]
shap.summary_plot(shap_no_base, plot_type="bar", feature_names=feature_names)

# %%
train_shap = pd.DataFrame(train[:,1:],columns=feature_names)

# %%
shap.summary_plot(shap_no_base, train_shap)

# %% [markdown]
# ### Local Explanations
#
# A local interprebility does not try to explian the whole AI model. Rather it trains XAI models that approximate individual predictions. Local interpretability models illustrate the outcomes of the models change when the values of specific features chaneg within a specific range.
#
# i.e the Churn probability change when customer age distribution changes.

# %%
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,
# ...

# %%
shap.force_plot(
    shap_base_value,
    shap_no_base[101, :],
    train_shap.iloc[101, :],
    link="logit",
    matplotlib=False,
)
# Out:
# <div id='iGB3SGB1WY1ZPR7ARBLGD'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
# ...

# %%
N_ROWS = shap_no_base.shape[0]
N_SAMPLES = min(100, N_ROWS)
sampled_indices = np.random.randint(N_ROWS, size=N_SAMPLES)

# %%
shap.force_plot(
    shap_base_value,
    shap_no_base[sampled_indices, :],
    train_shap.iloc[sampled_indices, :],
    link="logit",
)
# Out:
# <div id='iB065NUB64EAUG2JAQGQR'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
# ...

# %%
class ShapObject:
    
    def __init__(self, base_values, data, values, feature_names):
        self.base_values = base_values # Single value
        self.data = data # Raw feature values for 1 row of data
        self.values = values # SHAP values for the same row of data
        self.feature_names = feature_names # Column names
        

shap_object = ShapObject(base_values = shap_base_value,
                         values =  shap_no_base[101, :],
                         feature_names = feature_names,
                         data = train_shap.iloc[101, :])

shap.waterfall_plot(shap_object)

# %% [markdown]
# ### Try SM Clarify
#
# Now that you have your model set up. Let's try SageMaker Clarify to detetct bias and gain XAI!

# %%
from sagemaker import clarify

clarify_processor = clarify.SageMakerClarifyProcessor(
    role=role, instance_count=1, instance_type="ml.m5.xlarge", sagemaker_session=sagemaker_session
)

# %% [markdown]
# Detecting Bias
# SageMaker Clarify helps you detect possible pre- and post-training biases using a variety of metrics.
#
# Writing DataConfig and ModelConfig
# A DataConfig object communicates some basic information about data I/O to SageMaker Clarify. We specify where to find the input dataset, where to store the output, the target column (label), the header names, and the dataset type.

# %%
bias_report_output_path = "s3://{}/{}/clarify-bias".format(default_bucket, s3_prefix)
bias_data_config = clarify.DataConfig(
    s3_data_input_path=s3_input_train,
    s3_output_path=bias_report_output_path,
    label="Target",
    headers=pd.DataFrame(train).columns.to_list(),
    dataset_type="text/csv",
)

# %% [markdown]
# A ModelConfig object communicates information about your trained model. To avoid additional traffic to your production models, SageMaker Clarify sets up and tears down a dedicated endpoint when processing.
#
# instance_type and instance_count specify your preferred instance type and instance count used to run your model on during SageMaker Clarify's processing. The testing dataset is small so a single standard instance is good enough to run this example. If your have a large complex dataset, you may want to use a better instance type to speed up, or add more instances to enable Spark parallelization.
# accept_type denotes the endpoint response payload format, and content_type denotes the payload format of request to the endpoint.

# %%
model_name = 'churn-predict-endpoint-2021-12-06-17-47-26'
model_config = clarify.ModelConfig(
    model_name=model_name,
    instance_type="ml.m5.xlarge",
    instance_count=1,
    accept_type="text/csv",
    content_type="text/csv",
)

# %%
predictions_config = clarify.ModelPredictedLabelConfig(probability_threshold=0.8)

# %%
bias_config = clarify.BiasConfig(
    label_values_or_threshold=[1], facet_name="sex", facet_values_or_threshold=[0], group_name="is_married"
)

# %%
from sklearn import preprocessing


def number_encode_features(df):
    result = df.copy()
    encoders = {}
    for column in result.columns:
        if result.dtypes[column] == np.object:
            encoders[column] = preprocessing.LabelEncoder()
            #  print('Column:', column, result[column])
            result[column] = encoders[column].fit_transform(result[column].fillna("None"))
    return result, encoders


training_data = pd.concat([training_data["Target"], training_data.drop(["Target"], axis=1)], axis=1)
training_data, _ = number_encode_features(training_data)
training_data.to_csv("train_data.csv", index=False, header=False)

# %%
clarify_processor.run_bias(
    data_config=bias_data_config,
    bias_config=bias_config,
    model_config=model_config,
    model_predicted_label_config=predictions_config,
    pre_training_methods="all",
    post_training_methods="all",
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-69-61fb22b3cdfe> in <module>
# ----> 1 clarify_processor.run_bias(
#       2     data_config=bias_data_config,
#       3     bias_config=bias_config,
#       4     model_config=model_config,
#       5     model_predicted_label_config=predictions_config,
#
# ~/anaconda3/envs/aws/lib/python3.8/site-packages/sagemaker/clarify.py in run_bias(self, data_config, bias_config, model_config, model_predicted_label_config, pre_training_methods, post_training_methods, wait, logs, job_name, kms_key, experiment_config)
#    1020             else:
#    1021                 job_name = utils.name_from_base("Clarify-Bias")
# -> 1022         self._run(
#    1023             data_config,
#    1024             analysis_config,
#
# ...
